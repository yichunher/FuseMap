# %%
import sys
import pandas as pd
sys.path.append('/home/jialiulab/disk1/yichun/FuseMap/annotation_agent/')

from utils import *

# %%
llm = make_llm("gpt-4", temp=0)  # temp=0 for deterministic output

# %%
# path_ccfv3 = '/home/jialiulab/disk1/yichun/FuseMap/annotation_agent/data/structure_tree_safe_2017.csv'
# pd_ccfv3 = pd.read_csv(path_ccfv3)
# keep_column=['id','name','acronym','parent_structure_id','depth','structure_id_path','safe_name']
# pd_ccfv3 = pd_ccfv3[keep_column]
# pd_ccfv3.to_csv('/home/jialiulab/disk1/yichun/FuseMap/annotation_agent/data/ccfv3.csv',index=False)

# %%
pd_ccfv3=pd.read_csv('/home/jialiulab/disk1/yichun/FuseMap/annotation_agent/data/ccfv3.csv')#,index=False)

# %%
# Specify the file path
file_path = '/home/jialiulab/disk1/yichun/FuseMap/annotation_agent/data/Supplementary_Table_2.xlsx'

# Read the Excel file
df_main_tissue = pd.read_excel(file_path,sheet_name='Main level tissue regions')
df_sub_tissue = pd.read_excel(file_path,sheet_name='Sublevel tissue regions')

# %%
file_path='/home/jialiulab/disk1/yichun/FuseMap/annotation_agent/data/41586_2023_6569_MOESM7_ESM.xlsx'

df_celltype_starmap = pd.read_excel(file_path,sheet_name='Cell-type annotation')

# %%
file_path='/home/jialiulab/disk1/yichun/FuseMap/annotation_agent/data/41586_2023_6812_MOESM8_ESM.xlsx'

df_cluster_annotation_allen = pd.read_excel(file_path,sheet_name='cluster_annotation')

df_supertype_annotation_allen = pd.read_excel(file_path,sheet_name='supertype_annotation')

df_subclass_annotation_allen = pd.read_excel(file_path,sheet_name='subclass_annotation')

df_class_annotation_allen = pd.read_excel(file_path,sheet_name='class_annotation')

file_path='/home/jialiulab/disk1/yichun/FuseMap/annotation_agent/data/41586_2023_6812_MOESM8_ESM_column_header_explanation.xlsx'

df_column_header_explanation_allen = pd.read_excel(file_path)

# %%
df_column_header_explanation_allen
# Out:
#         cl  cluster_id              cluster_id_label  supertype_id  \
# 0      128           1  0001 CLA-EPd-CTX Car3 Glut_1             1
# 1      129           2  0002 CLA-EPd-CTX Car3 Glut_1             1
# 2      130           3  0003 CLA-EPd-CTX Car3 Glut_1             1
# 3      143           4  0004 CLA-EPd-CTX Car3 Glut_1             1
# 4      131           5  0005 CLA-EPd-CTX Car3 Glut_2             2
# ...    ...         ...                           ...           ...
# 5317  5279        5318                  5318 DC NN_1          1197
# 5318  5275        5319             5319 B cells NN_1          1198
# 5319  5272        5320                 5320 ILC NN_2          1199
# 5320  5274        5321            5321 NK cells NN_3          1200
# 5321  5273        5322             5322 T cells NN_4          1201
#
#               supertype_label            supertype_id_label  subclass_id  \
# 0     CLA-EPd-CTX Car3 Glut_1  0001 CLA-EPd-CTX Car3 Glut_1            1
# ...
